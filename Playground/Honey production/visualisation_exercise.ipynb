# %%
import pandas as pd
df = pd.read_csv('honeyproduction.csv')
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# 5      FL  230000.0           98  22540000.0   4508000.0        0.64
# 6      GA   75000.0           56   4200000.0    307000.0        0.69
# 7      HI    8000.0          118    944000.0     66000.0        0.77
# 8      ID  120000.0           50   6000000.0   2220000.0        0.65
# 9      IL    9000.0           71    639000.0    204000.0        1.19
# 10     IN    9000.0           92    828000.0    489000.0        0.85
# 11     IA   50000.0           78   3900000.0   2301000.0        0.70
# 12     KS   16000.0           46    736000.0    390000.0        0.87
# ...

# %%
print(df.columns)
print(df.shape)
remove_cols = ['state', 'numcol',  'totalprod', 'stocks', 'priceperlb',
       'prodvalue']
#df.drop(remove_cols, axis = 1)
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='object')
# (626, 8)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
#sns.FacetGrid(df, hue = 'year', size = 10).map(plt.scatter, 'yieldpercol').add_legend()
sns.pairplot(df, hue = 'year', size = 10);

# %%
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# 5      FL  230000.0           98  22540000.0   4508000.0        0.64
# 6      GA   75000.0           56   4200000.0    307000.0        0.69
# 7      HI    8000.0          118    944000.0     66000.0        0.77
# 8      ID  120000.0           50   6000000.0   2220000.0        0.65
# 9      IL    9000.0           71    639000.0    204000.0        1.19
# 10     IN    9000.0           92    828000.0    489000.0        0.85
# 11     IA   50000.0           78   3900000.0   2301000.0        0.70
# 12     KS   16000.0           46    736000.0    390000.0        0.87
# ...

# %%
df1  =  df[['state', 'totalprod', 'prodvalue']]
df1
# Out:
#     state   totalprod   prodvalue
# 0      AL   1136000.0    818000.0
# 1      AZ   3300000.0   2112000.0
# 2      AR   3445000.0   2033000.0
# 3      CA  37350000.0  23157000.0
# 4      CO   1944000.0   1361000.0
# 5      FL  22540000.0  14426000.0
# 6      GA   4200000.0   2898000.0
# 7      HI    944000.0    727000.0
# 8      ID   6000000.0   3900000.0
# 9      IL    639000.0    760000.0
# 10     IN    828000.0    704000.0
# 11     IA   3900000.0   2730000.0
# 12     KS    736000.0    640000.0
# 13     KY    150000.0    210000.0
# 14     LA   4551000.0   2685000.0
# 15     ME    260000.0    179000.0
# 16     MD    308000.0    339000.0
# 17     MI   6800000.0   4488000.0
# 18     MN  11060000.0   7189000.0
# 19     MS   1548000.0    898000.0
# 20     MO   1518000.0   1154000.0
# 21     MT  14030000.0   8979000.0
# 22     NE   4480000.0   3853000.0
# 23     NV    460000.0    759000.0
# 24     NJ    539000.0    410000.0
# 25     NM    770000.0    585000.0
# ...

# %%
'''fig = sns.swarmplot(x="state", y="totalprod",  data=df,  edgecolor="gray")
fig.autofmt_xdate()'''

sns.FacetGrid(df1, hue = 'state', size = 10).map(sns.distplot, 'totalprod').add_legend()
plt.show()
